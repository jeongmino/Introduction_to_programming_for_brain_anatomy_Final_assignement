# %% [markdown]
# <p style="text-align: center; font-size: 30px" > Final Assignment </p>
#
# <p style="text-align: right; font-size: 20px"> BRI519 (Fall/2025) </p>
#
# <p style="text-align: right; font-size: 15px"> Provided on December 12 (Friday) and due on December 23 (Tuesday) </p>
#
# <br>
#
# Your name:
# <br>
#
# Your ID:

# %% [markdown]
# ## General Notes
#
# (i) Please **do not discuss** this assignment with your friends. Instead, develop your own ideas independently, using AI tools if necessary. If you use any AI tools, explicitly state which tools were used in the corresponding notebook cell.
#
# (ii) Please write your responses in **English**.
#
# <br>
#
# Please submit **your Github repository URL**, **Docker Hub image URL** to the TA (neti2207@korea.ac.kr) and instructor (jonghwan_lee@korea.ac.kr) <br>
#
# If you have any issues, please reach out to the TA via an email.    <br>

# %% [markdown]
# ## Question 1 : Github Repository - Project Setup and Documentation
# [**Goal**] Transform your midterm submission into a **well-documented**, **modular project on Github** with proper version control practices.
#
# <br>
#
# Please complete the following tasks:

# %% [markdown]
# (1) Create a **new Github repository** and initialize it with your **midterm project code**.

# %% [markdown]
# (2) **Write** comprehensive documentation including :
# * **README.md** with project overview, installation instructions, and usage examples.
# * **Inline code comments** explaining key functions and logic.

# %% [markdown]
# (3) **Refactor your code** into modular components :
# * Separate **functionality** into logical modules.
# * Implement proper **function** and **class** structures.
# * Ensure code **reusability** and **maintainability**.

# %% [markdown]
# (4) **Complete any unfinished code** from your midterm submission :
# * Fix bugs and errors
# * Implement missing features
# * Ensure all functionality works as intended

# %% [markdown]
# (5) **Commit your changes incrementally using meaningful commit messages** :
# * Use **step-by-step commits** (e.g., “Add module A”, “Implement module B”, “Update documentation”)
# * Each commit should represent a **logical unit of work**
# * Write clear, descriptive **commit messages**

# %% [markdown]
# (6) **Invite** the TA as a **collaborator** to your repository (TA : **neti69@naver.com**, Instructor : **bsplku-jhlee**)

# %% [markdown]
# ## Question 2 : Docker Containerization and Deployment
# [**Goal**] **Containerize** your project using **Docker** and deploy it to **Docker Hub** for reproducible execution.
#
# <br>
#
# Please complete the following tasks:

# %% [markdown]
# (1) Create a **Dockerfile** that:
# * Sets up the appropriate base image and environment.
# * Installs all necessary dependencies.
# * **Copies the code you wrote in Question 1 into the container.**
# * Configures the entry point or command to run your application.

# %% [markdown]
# (2) **Build and test** your Docker image locally :
# * Ensure the container runs successfully.
# * Verify that **output matches your results of Question 1**.

# %% [markdown]
# (3) **Push your Docker image** to Docker Hub :
# * Create a Docker Hub account if needed.
# * Tag your image appropriately.
# * Upload the image to your Docker Hub repository.

# %% [markdown]
# (4) **Document the Docker setup in your README.md** :
# * Add instructions for building the Docker image.
# * Provide commands for running the container.
# * Include the Docker Hub image link.

# %% [markdown]
# (5) **Verify the deployment** :
# * Pull and run your image from Docker Hub
# * Confirm identical output to local execution

# %% [markdown]
# End of assignment
